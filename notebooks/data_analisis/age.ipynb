# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
from pathlib import Path
from glob import glob

# %%
base_path = "/home/transaction-generation/data/age/*"
glob(base_path)
# Out:
# ['/home/transaction-generation/data/age/preprocessed',
#  '/home/transaction-generation/data/age/transactions_train.csv',
#  '/home/transaction-generation/data/age/train_target.csv',
#  '/home/transaction-generation/data/age/small_group_description.csv',
#  '/home/transaction-generation/data/age/transactions_test.csv',
#  '/home/transaction-generation/data/age/test.csv']

# %% [markdown]
# ## Preprocessed check

# %%
pd.read_parquet("/home/transaction-generation/data/age/preprocessed/train")._seq_len.max()
# Out:
# 1150

# %% [markdown]
# ## Trans date

# %%
df = pd.read_csv('/home/transaction-generation/data/age/transactions_train.csv')

# %%
df.amount_rur.mean()
# Out:
# 55.86215236340578

# %%
df[df.trans_date < 365].trans_date.hist()
# Out:
# <Axes: >

# %%
df[df.trans_date >= 365].trans_date.hist()
# Out:
# <Axes: >
